# %%
# %pylab inline
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
import scanpy as sc
import pandas as pd
import torch
import scipy
import time
from STEM.model import *
from STEM.utils import *
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
scdata = pd.read_csv('./data/mousedata_2020/E3z2/counts.csv',index_col=0)
scdata = scdata.T
stdata = pd.read_csv('./data/mousedata_2020/E3z2/simu_st_counts.csv',index_col=0)
stdata = stdata.T
stgtcelltype = pd.read_csv('./data/mousedata_2020/E3z2/simu_st_celltype.csv',index_col=0)
spcoor = pd.read_csv('./data/mousedata_2020/E3z2/simu_st_metadata.csv',index_col=0)
scmetadata = pd.read_csv('./data/mousedata_2020/E3z2/metadata.csv',index_col=0)

adata = sc.AnnData(scdata,obs=scmetadata)
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
scdata = pd.DataFrame(adata.X,index=adata.obs_names,columns=adata.var_names)
stadata = sc.AnnData(stdata)
sc.pp.normalize_total(stadata)
sc.pp.log1p(stadata)
stdata = pd.DataFrame(stadata.X,index=stadata.obs_names,columns=stadata.var_names)

adata.obsm['spatial'] = scmetadata[['x_global','y_global']].values
stadata.obsm['spatial'] = spcoor

# %%
sc.pp.calculate_qc_metrics(adata,percent_top=None, log1p=False, inplace=True)
sc.pp.calculate_qc_metrics(stadata,percent_top=None, log1p=False, inplace=True)

# %%
dp = 1- adata.obs['n_genes_by_counts'].median()/stadata.obs['n_genes_by_counts'].median()

# %%
figsize(2,2)
sc.pl.violin(stadata, ['n_genes_by_counts', 'total_counts'],jitter=0.4, multi_panel=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'],jitter=0.4, multi_panel=True)
# Out:
# /home/hms/anaconda3/envs/scpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'orig.ident' as categorical
# /home/hms/anaconda3/envs/scpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'embryo' as categorical
# /home/hms/anaconda3/envs/scpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'pos' as categorical
# /home/hms/anaconda3/envs/scpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'embryo_pos' as categorical
# /home/hms/anaconda3/envs/scpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'embryo_pos_z' as categorical
# /home/hms/anaconda3/envs/scpy/lib/python3.8/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'celltype_mapped_refined' as categorical

# %%
class setting( object ):
    pass
seed_all(2022)
opt= setting()
setattr(opt, 'device', 'cuda:0')
setattr(opt, 'outf', 'log/Mouse_E3z2')
setattr(opt, 'n_genes', 351)
setattr(opt, 'no_bn', False)
setattr(opt, 'lr', 0.002)
setattr(opt, 'sigma', 7)
setattr(opt, 'alpha', 0.8)
setattr(opt, 'verbose', True)
setattr(opt, 'mmdbatch', 1000)
setattr(opt, 'dp', dp)

# %%
# %%time
testmodel =  SOmodel(opt)
testmodel.togpu()
loss_curve = testmodel.train_wholedata(400,torch.tensor(scdata.values).float(),torch.tensor(stdata.values).float(),torch.tensor(spcoor.values).float())
# Out:
# [Train][0] Loss: E 2.935 E_pred 2.875 E_circle 5.201 E_mmd 0.075
# [0.002]
# [Train][1] Loss: E 4.268 E_pred 4.233 E_circle 5.645 E_mmd 0.043
# [0.002]
# [Train][2] Loss: E 3.267 E_pred 3.231 E_circle 5.280 E_mmd 0.046
# [0.002]
# [Train][3] Loss: E 2.839 E_pred 2.807 E_circle 4.999 E_mmd 0.041
# [0.002]
# [Train][4] Loss: E 2.696 E_pred 2.669 E_circle 4.846 E_mmd 0.034
# [0.002]
# [Train][5] Loss: E 2.844 E_pred 2.813 E_circle 4.754 E_mmd 0.039
# [0.002]
# [Train][6] Loss: E 2.668 E_pred 2.639 E_circle 4.718 E_mmd 0.035
# [0.002]
# [Train][7] Loss: E 2.632 E_pred 2.602 E_circle 4.313 E_mmd 0.037
# [0.002]
# [Train][8] Loss: E 2.566 E_pred 2.539 E_circle 4.466 E_mmd 0.034
# [0.002]
# [Train][9] Loss: E 2.527 E_pred 2.501 E_circle 4.293 E_mmd 0.032
# [0.002]
# [Train][10] Loss: E 2.547 E_pred 2.523 E_circle 4.413 E_mmd 0.030
# [0.002]
# [Train][11] Loss: E 2.492 E_pred 2.469 E_circle 4.201 E_mmd 0.029
# [0.002]
# [Train][12] Loss: E 2.500 E_pred 2.478 E_circle 4.091 E_mmd 0.027
# [0.002]
# [Train][13] Loss: E 2.490 E_pred 2.465 E_circle 4.058 E_mmd 0.031
# [0.002]
# [Train][14] Loss: E 2.426 E_pred 2.400 E_circle 4.078 E_mmd 0.032
# [0.002]
# [Train][15] Loss: E 2.444 E_pred 2.422 E_circle 4.134 E_mmd 0.027
# [0.002]
# [Train][16] Loss: E 2.419 E_pred 2.397 E_circle 4.048 E_mmd 0.029
# [0.002]
# [Train][17] Loss: E 2.384 E_pred 2.365 E_circle 3.897 E_mmd 0.023
# [0.002]
# [Train][18] Loss: E 2.373 E_pred 2.354 E_circle 3.967 E_mmd 0.024
# [0.002]
# [Train][19] Loss: E 2.381 E_pred 2.361 E_circle 3.980 E_mmd 0.025
# [0.002]
# [Train][20] Loss: E 2.326 E_pred 2.308 E_circle 3.975 E_mmd 0.023
# [0.002]
# [Train][21] Loss: E 2.353 E_pred 2.336 E_circle 3.959 E_mmd 0.022
# [0.002]
# [Train][22] Loss: E 2.317 E_pred 2.299 E_circle 3.863 E_mmd 0.022
# [0.002]
# [Train][23] Loss: E 2.332 E_pred 2.314 E_circle 3.836 E_mmd 0.022
# [0.002]
# [Train][24] Loss: E 2.277 E_pred 2.261 E_circle 3.785 E_mmd 0.021
# [0.002]
# [Train][25] Loss: E 2.297 E_pred 2.279 E_circle 3.820 E_mmd 0.022
# [0.002]
# [Train][26] Loss: E 2.276 E_pred 2.258 E_circle 3.856 E_mmd 0.023
# [0.002]
# [Train][27] Loss: E 2.308 E_pred 2.292 E_circle 3.843 E_mmd 0.020
# [0.002]
# [Train][28] Loss: E 2.250 E_pred 2.233 E_circle 3.769 E_mmd 0.021
# [0.002]
# [Train][29] Loss: E 2.274 E_pred 2.255 E_circle 3.755 E_mmd 0.024
# [0.002]
# [Train][30] Loss: E 2.189 E_pred 2.172 E_circle 3.664 E_mmd 0.021
# [0.002]
# [Train][31] Loss: E 2.231 E_pred 2.213 E_circle 3.721 E_mmd 0.022
# [0.002]
# [Train][32] Loss: E 2.255 E_pred 2.238 E_circle 3.788 E_mmd 0.022
# [0.002]
# [Train][33] Loss: E 2.220 E_pred 2.204 E_circle 3.716 E_mmd 0.020
# [0.002]
# [Train][34] Loss: E 2.241 E_pred 2.224 E_circle 3.705 E_mmd 0.021
# [0.002]
# [Train][35] Loss: E 2.226 E_pred 2.212 E_circle 3.633 E_mmd 0.018
# [0.002]
# [Train][36] Loss: E 2.165 E_pred 2.147 E_circle 3.572 E_mmd 0.022
# [0.002]
# [Train][37] Loss: E 2.173 E_pred 2.159 E_circle 3.619 E_mmd 0.018
# [0.002]
# [0.002]
# [Train][69] Loss: E 2.233 E_pred 2.048 E_circle 3.198 E_mmd 0.015
# [0.002]
# [Train][70] Loss: E 2.272 E_pred 2.074 E_circle 3.238 E_mmd 0.016
# [0.002]
# [Train][71] Loss: E 2.266 E_pred 2.060 E_circle 3.223 E_mmd 0.017
# [0.002]
# [Train][72] Loss: E 2.274 E_pred 2.057 E_circle 3.221 E_mmd 0.019
# [0.002]
# [Train][73] Loss: E 2.246 E_pred 2.027 E_circle 3.135 E_mmd 0.016
# [0.002]
# [Train][74] Loss: E 2.243 E_pred 2.016 E_circle 3.115 E_mmd 0.016
# [0.002]
# [Train][75] Loss: E 2.314 E_pred 2.072 E_circle 3.166 E_mmd 0.019
# [0.002]
# [Train][76] Loss: E 2.287 E_pred 2.040 E_circle 3.150 E_mmd 0.017
# [0.002]
# [Train][77] Loss: E 2.263 E_pred 2.012 E_circle 3.087 E_mmd 0.016
# [0.002]
# [Train][78] Loss: E 2.325 E_pred 2.059 E_circle 3.157 E_mmd 0.017
# [0.002]
# [Train][79] Loss: E 2.329 E_pred 2.056 E_circle 3.113 E_mmd 0.019
# [0.002]
# [Train][80] Loss: E 2.332 E_pred 2.053 E_circle 3.107 E_mmd 0.016
# [0.002]
# [Train][81] Loss: E 2.288 E_pred 2.003 E_circle 3.079 E_mmd 0.016
# [0.002]
# [Train][82] Loss: E 2.307 E_pred 2.016 E_circle 3.057 E_mmd 0.014
# [0.002]
# [Train][83] Loss: E 2.306 E_pred 2.005 E_circle 3.059 E_mmd 0.015
# [0.002]
# [Train][84] Loss: E 2.319 E_pred 2.012 E_circle 3.025 E_mmd 0.017
# [0.002]
# [Train][85] Loss: E 2.321 E_pred 2.008 E_circle 3.003 E_mmd 0.017
# [0.002]
# [Train][86] Loss: E 2.320 E_pred 2.006 E_circle 2.923 E_mmd 0.017
# [0.002]
# [Train][87] Loss: E 2.320 E_pred 1.996 E_circle 2.942 E_mmd 0.016
# [0.002]
# [Train][88] Loss: E 2.324 E_pred 1.991 E_circle 2.943 E_mmd 0.017
# [0.002]
# [Train][89] Loss: E 2.338 E_pred 1.997 E_circle 2.965 E_mmd 0.013
# [0.002]
# [Train][90] Loss: E 2.349 E_pred 1.995 E_circle 2.979 E_mmd 0.016
# [0.002]
# [Train][91] Loss: E 2.355 E_pred 2.000 E_circle 2.907 E_mmd 0.018
# [0.002]
# [Train][92] Loss: E 2.373 E_pred 2.009 E_circle 2.918 E_mmd 0.018
# [0.002]
# [Train][93] Loss: E 2.406 E_pred 2.034 E_circle 2.923 E_mmd 0.016
# [0.002]
# [Train][94] Loss: E 2.395 E_pred 2.012 E_circle 2.943 E_mmd 0.016
# [0.002]
# [Train][95] Loss: E 2.425 E_pred 2.034 E_circle 2.927 E_mmd 0.018
# [0.002]
# [Train][96] Loss: E 2.392 E_pred 1.999 E_circle 2.883 E_mmd 0.017
# [0.002]
# [Train][97] Loss: E 2.376 E_pred 1.980 E_circle 2.848 E_mmd 0.017
# [0.002]
# [Train][98] Loss: E 2.427 E_pred 2.023 E_circle 2.846 E_mmd 0.016
# [0.002]
# [Train][99] Loss: E 2.390 E_pred 1.983 E_circle 2.826 E_mmd 0.014
# [0.002]
# [Train][100] Loss: E 2.428 E_pred 2.005 E_circle 2.876 E_mmd 0.015
# [0.002]
# [Train][101] Loss: E 2.402 E_pred 1.977 E_circle 2.828 E_mmd 0.015
# [0.002]
# [Train][102] Loss: E 2.413 E_pred 1.985 E_circle 2.794 E_mmd 0.016
# [0.002]
# [Train][103] Loss: E 2.412 E_pred 1.974 E_circle 2.801 E_mmd 0.017
# [0.002]
# [Train][104] Loss: E 2.453 E_pred 2.006 E_circle 2.803 E_mmd 0.018
# [0.002]
# [Train][105] Loss: E 2.426 E_pred 1.981 E_circle 2.751 E_mmd 0.015
# [0.002]
# [Train][106] Loss: E 2.436 E_pred 1.980 E_circle 2.764 E_mmd 0.017
# [0.002]
# [Train][107] Loss: E 2.452 E_pred 1.982 E_circle 2.804 E_mmd 0.016
# [0.002]
# [Train][108] Loss: E 2.509 E_pred 2.023 E_circle 2.836 E_mmd 0.020
# [0.002]
# [Train][109] Loss: E 2.470 E_pred 2.000 E_circle 2.713 E_mmd 0.016
# [0.002]
# [Train][110] Loss: E 2.458 E_pred 1.985 E_circle 2.677 E_mmd 0.018
# [0.002]
# [Train][111] Loss: E 2.452 E_pred 1.972 E_circle 2.677 E_mmd 0.017
# [0.002]
# [Train][112] Loss: E 2.484 E_pred 1.983 E_circle 2.750 E_mmd 0.017
# [0.002]
# [Train][113] Loss: E 2.433 E_pred 1.944 E_circle 2.644 E_mmd 0.017
# [0.002]
# [Train][114] Loss: E 2.460 E_pred 1.963 E_circle 2.647 E_mmd 0.017
# [0.002]
# [Train][115] Loss: E 2.474 E_pred 1.969 E_circle 2.648 E_mmd 0.016
# [0.002]
# [Train][116] Loss: E 2.439 E_pred 1.935 E_circle 2.605 E_mmd 0.016
# [0.002]
# [Train][117] Loss: E 2.453 E_pred 1.940 E_circle 2.608 E_mmd 0.016
# [0.002]
# [Train][118] Loss: E 2.488 E_pred 1.969 E_circle 2.599 E_mmd 0.018
# [0.002]
# [Train][119] Loss: E 2.472 E_pred 1.947 E_circle 2.600 E_mmd 0.015
# [0.002]
# [Train][120] Loss: E 2.494 E_pred 1.957 E_circle 2.623 E_mmd 0.015
# [0.002]
# [Train][121] Loss: E 2.486 E_pred 1.947 E_circle 2.596 E_mmd 0.015
# [0.002]
# [Train][122] Loss: E 2.521 E_pred 1.974 E_circle 2.586 E_mmd 0.019
# [0.002]
# [Train][123] Loss: E 2.492 E_pred 1.950 E_circle 2.533 E_mmd 0.017
# [0.002]
# [Train][124] Loss: E 2.502 E_pred 1.945 E_circle 2.569 E_mmd 0.018
# [0.002]
# [Train][125] Loss: E 2.497 E_pred 1.942 E_circle 2.523 E_mmd 0.018
# [0.002]
# [Train][126] Loss: E 2.512 E_pred 1.945 E_circle 2.549 E_mmd 0.017
# [0.002]
# [Train][127] Loss: E 2.552 E_pred 1.973 E_circle 2.561 E_mmd 0.020
# [0.002]
# [Train][128] Loss: E 2.488 E_pred 1.918 E_circle 2.492 E_mmd 0.018
# [0.002]
# [Train][129] Loss: E 2.566 E_pred 1.964 E_circle 2.591 E_mmd 0.022
# [0.002]
# [Train][130] Loss: E 2.567 E_pred 1.969 E_circle 2.546 E_mmd 0.020
# [0.002]
# [Train][131] Loss: E 2.529 E_pred 1.942 E_circle 2.465 E_mmd 0.020
# [0.002]
# [Train][132] Loss: E 2.519 E_pred 1.942 E_circle 2.407 E_mmd 0.017
# [0.002]
# [Train][133] Loss: E 2.566 E_pred 1.961 E_circle 2.484 E_mmd 0.020
# [0.002]
# [Train][134] Loss: E 2.541 E_pred 1.933 E_circle 2.466 E_mmd 0.021
# [0.002]
# [Train][135] Loss: E 2.519 E_pred 1.913 E_circle 2.433 E_mmd 0.020
# [0.002]
# [Train][136] Loss: E 2.503 E_pred 1.904 E_circle 2.378 E_mmd 0.019
# [0.002]
# [Train][137] Loss: E 2.529 E_pred 1.921 E_circle 2.389 E_mmd 0.017
# [0.002]
# [Train][138] Loss: E 2.576 E_pred 1.956 E_circle 2.410 E_mmd 0.017
# [0.002]
# [Train][139] Loss: E 2.529 E_pred 1.914 E_circle 2.362 E_mmd 0.018
# [0.002]
# [Train][140] Loss: E 2.582 E_pred 1.937 E_circle 2.449 E_mmd 0.019
# [0.002]
# [Train][141] Loss: E 2.534 E_pred 1.905 E_circle 2.361 E_mmd 0.020
# [0.002]
# [Train][142] Loss: E 2.562 E_pred 1.934 E_circle 2.325 E_mmd 0.021
# [0.002]
# [Train][143] Loss: E 2.591 E_pred 1.954 E_circle 2.339 E_mmd 0.019
# [0.002]
# [Train][144] Loss: E 2.554 E_pred 1.908 E_circle 2.343 E_mmd 0.021
# [0.002]
# [Train][145] Loss: E 2.573 E_pred 1.907 E_circle 2.392 E_mmd 0.022
# [0.002]
# [Train][146] Loss: E 2.537 E_pred 1.889 E_circle 2.307 E_mmd 0.019
# [0.002]
# [Train][147] Loss: E 2.580 E_pred 1.917 E_circle 2.331 E_mmd 0.021
# [0.002]
# [Train][148] Loss: E 2.577 E_pred 1.923 E_circle 2.285 E_mmd 0.017
# [0.002]
# [Train][149] Loss: E 2.577 E_pred 1.919 E_circle 2.268 E_mmd 0.021
# [0.002]
# [Train][150] Loss: E 2.546 E_pred 1.890 E_circle 2.239 E_mmd 0.021
# [0.002]
# [Train][151] Loss: E 2.632 E_pred 1.948 E_circle 2.314 E_mmd 0.020
# [0.002]
# [Train][152] Loss: E 2.603 E_pred 1.925 E_circle 2.272 E_mmd 0.020
# [0.002]
# [Train][153] Loss: E 2.584 E_pred 1.895 E_circle 2.284 E_mmd 0.020
# [0.002]
# [Train][154] Loss: E 2.642 E_pred 1.941 E_circle 2.303 E_mmd 0.020
# [0.002]
# [Train][155] Loss: E 2.629 E_pred 1.924 E_circle 2.295 E_mmd 0.021
# [0.002]
# [Train][156] Loss: E 2.607 E_pred 1.908 E_circle 2.256 E_mmd 0.021
# [0.002]
# [Train][157] Loss: E 2.632 E_pred 1.928 E_circle 2.248 E_mmd 0.022
# [0.002]
# [Train][158] Loss: E 2.578 E_pred 1.888 E_circle 2.185 E_mmd 0.020
# [0.002]
# [Train][159] Loss: E 2.643 E_pred 1.922 E_circle 2.261 E_mmd 0.022
# [0.002]
# [0.002]
# [Train][191] Loss: E 2.652 E_pred 1.837 E_circle 1.973 E_mmd 0.025
# [0.002]
# [Train][192] Loss: E 2.654 E_pred 1.854 E_circle 1.926 E_mmd 0.023
# [0.002]
# [Train][193] Loss: E 2.706 E_pred 1.885 E_circle 1.961 E_mmd 0.025
# [0.002]
# [Train][194] Loss: E 2.787 E_pred 1.922 E_circle 2.038 E_mmd 0.033
# [0.002]
# [Train][195] Loss: E 2.697 E_pred 1.853 E_circle 1.985 E_mmd 0.028
# [0.002]
# [Train][196] Loss: E 2.730 E_pred 1.878 E_circle 1.985 E_mmd 0.031
# [0.002]
# [Train][197] Loss: E 2.784 E_pred 1.930 E_circle 1.984 E_mmd 0.026
# [0.002]
# [Train][198] Loss: E 2.704 E_pred 1.860 E_circle 1.945 E_mmd 0.027
# [0.002]
# [Train][199] Loss: E 2.706 E_pred 1.852 E_circle 1.958 E_mmd 0.026
# [0.001]
# [Train][200] Loss: E 2.724 E_pred 1.890 E_circle 1.891 E_mmd 0.030
# [0.001]
# [Train][201] Loss: E 2.688 E_pred 1.862 E_circle 1.868 E_mmd 0.025
# [0.001]
# [Train][202] Loss: E 2.684 E_pred 1.847 E_circle 1.878 E_mmd 0.026
# [0.001]
# [Train][203] Loss: E 2.714 E_pred 1.847 E_circle 1.929 E_mmd 0.029
# [0.001]
# [Train][204] Loss: E 2.724 E_pred 1.860 E_circle 1.911 E_mmd 0.028
# [0.001]
# [Train][205] Loss: E 2.725 E_pred 1.865 E_circle 1.893 E_mmd 0.027
# [0.001]
# [Train][206] Loss: E 2.718 E_pred 1.838 E_circle 1.922 E_mmd 0.029
# [0.001]
# [Train][207] Loss: E 2.721 E_pred 1.845 E_circle 1.906 E_mmd 0.027
# [0.001]
# [Train][208] Loss: E 2.676 E_pred 1.806 E_circle 1.873 E_mmd 0.031
# [0.001]
# [Train][209] Loss: E 2.720 E_pred 1.829 E_circle 1.904 E_mmd 0.031
# [0.001]
# [Train][210] Loss: E 2.772 E_pred 1.886 E_circle 1.886 E_mmd 0.030
# [0.001]
# [Train][211] Loss: E 2.716 E_pred 1.850 E_circle 1.833 E_mmd 0.029
# [0.001]
# [Train][212] Loss: E 2.722 E_pred 1.851 E_circle 1.833 E_mmd 0.028
# [0.001]
# [Train][213] Loss: E 2.741 E_pred 1.862 E_circle 1.835 E_mmd 0.030
# [0.001]
# [Train][214] Loss: E 2.732 E_pred 1.863 E_circle 1.806 E_mmd 0.028
# [0.001]
# [Train][215] Loss: E 2.691 E_pred 1.821 E_circle 1.794 E_mmd 0.030
# [0.001]
# [Train][216] Loss: E 2.709 E_pred 1.834 E_circle 1.799 E_mmd 0.027
# [0.001]
# [Train][217] Loss: E 2.733 E_pred 1.840 E_circle 1.824 E_mmd 0.027
# [0.001]
# [Train][218] Loss: E 2.745 E_pred 1.833 E_circle 1.851 E_mmd 0.030
# [0.001]
# [Train][219] Loss: E 2.704 E_pred 1.812 E_circle 1.802 E_mmd 0.027
# [0.001]
# [Train][220] Loss: E 2.722 E_pred 1.830 E_circle 1.791 E_mmd 0.028
# [0.001]
# [0.001]
# [Train][252] Loss: E 2.790 E_pred 1.808 E_circle 1.652 E_mmd 0.036
# [0.001]
# [Train][253] Loss: E 2.714 E_pred 1.773 E_circle 1.577 E_mmd 0.033
# [0.001]
# [Train][254] Loss: E 2.843 E_pred 1.858 E_circle 1.641 E_mmd 0.035
# [0.001]
# [Train][255] Loss: E 2.803 E_pred 1.830 E_circle 1.617 E_mmd 0.031
# [0.001]
# [Train][256] Loss: E 2.823 E_pred 1.810 E_circle 1.672 E_mmd 0.037
# [0.001]
# [Train][257] Loss: E 2.714 E_pred 1.768 E_circle 1.558 E_mmd 0.031
# [0.001]
# [Train][258] Loss: E 2.861 E_pred 1.844 E_circle 1.663 E_mmd 0.036
# [0.001]
# [Train][259] Loss: E 2.823 E_pred 1.835 E_circle 1.609 E_mmd 0.033
# [0.001]
# [Train][260] Loss: E 2.778 E_pred 1.805 E_circle 1.579 E_mmd 0.032
# [0.001]
# [Train][261] Loss: E 2.763 E_pred 1.790 E_circle 1.568 E_mmd 0.035
# [0.001]
# [Train][262] Loss: E 2.921 E_pred 1.885 E_circle 1.657 E_mmd 0.041
# [0.001]
# [Train][263] Loss: E 2.830 E_pred 1.824 E_circle 1.603 E_mmd 0.038
# [0.001]
# [Train][264] Loss: E 2.841 E_pred 1.822 E_circle 1.618 E_mmd 0.039
# [0.001]
# [Train][265] Loss: E 2.906 E_pred 1.861 E_circle 1.649 E_mmd 0.040
# [0.001]
# [Train][266] Loss: E 2.902 E_pred 1.871 E_circle 1.614 E_mmd 0.044
# [0.001]
# [Train][267] Loss: E 2.924 E_pred 1.871 E_circle 1.645 E_mmd 0.042
# [0.001]
# [Train][268] Loss: E 2.787 E_pred 1.798 E_circle 1.537 E_mmd 0.039
# [0.001]
# [Train][269] Loss: E 2.818 E_pred 1.804 E_circle 1.573 E_mmd 0.038
# [0.001]
# [Train][270] Loss: E 2.793 E_pred 1.787 E_circle 1.549 E_mmd 0.040
# [0.001]
# [Train][271] Loss: E 2.821 E_pred 1.846 E_circle 1.497 E_mmd 0.038
# [0.001]
# [Train][272] Loss: E 2.819 E_pred 1.828 E_circle 1.514 E_mmd 0.039
# [0.001]
# [Train][273] Loss: E 2.849 E_pred 1.836 E_circle 1.538 E_mmd 0.041
# [0.001]
# [Train][274] Loss: E 2.790 E_pred 1.778 E_circle 1.531 E_mmd 0.039
# [0.001]
# [Train][275] Loss: E 2.862 E_pred 1.809 E_circle 1.589 E_mmd 0.039
# [0.001]
# [Train][276] Loss: E 2.860 E_pred 1.803 E_circle 1.589 E_mmd 0.039
# [0.001]
# [Train][277] Loss: E 2.848 E_pred 1.824 E_circle 1.531 E_mmd 0.038
# [0.001]
# [Train][278] Loss: E 2.844 E_pred 1.822 E_circle 1.525 E_mmd 0.036
# [0.001]
# [Train][279] Loss: E 2.800 E_pred 1.795 E_circle 1.487 E_mmd 0.040
# [0.001]
# [Train][280] Loss: E 2.831 E_pred 1.796 E_circle 1.527 E_mmd 0.040
# [0.001]
# [Train][281] Loss: E 2.804 E_pred 1.788 E_circle 1.493 E_mmd 0.038
# [0.001]
# [Train][282] Loss: E 2.902 E_pred 1.852 E_circle 1.534 E_mmd 0.042
# [0.001]
# [Train][283] Loss: E 2.878 E_pred 1.823 E_circle 1.529 E_mmd 0.046
# [0.001]
# [Train][284] Loss: E 2.907 E_pred 1.852 E_circle 1.530 E_mmd 0.040
# [0.001]
# [Train][285] Loss: E 2.834 E_pred 1.791 E_circle 1.506 E_mmd 0.040
# [0.001]
# [Train][286] Loss: E 2.848 E_pred 1.793 E_circle 1.510 E_mmd 0.046
# [0.001]
# [Train][287] Loss: E 2.848 E_pred 1.794 E_circle 1.504 E_mmd 0.045
# [0.001]
# [Train][288] Loss: E 2.917 E_pred 1.843 E_circle 1.527 E_mmd 0.045
# [0.001]
# [Train][289] Loss: E 2.857 E_pred 1.820 E_circle 1.464 E_mmd 0.046
# [0.001]
# [Train][290] Loss: E 2.835 E_pred 1.806 E_circle 1.454 E_mmd 0.039
# [0.001]
# [Train][291] Loss: E 2.870 E_pred 1.800 E_circle 1.503 E_mmd 0.043
# [0.001]
# [Train][292] Loss: E 2.873 E_pred 1.805 E_circle 1.498 E_mmd 0.041
# [0.001]
# [Train][293] Loss: E 2.841 E_pred 1.779 E_circle 1.476 E_mmd 0.046
# [0.001]
# [Train][294] Loss: E 2.894 E_pred 1.819 E_circle 1.493 E_mmd 0.042
# [0.001]
# [Train][295] Loss: E 2.840 E_pred 1.808 E_circle 1.428 E_mmd 0.041
# [0.001]
# [Train][296] Loss: E 2.908 E_pred 1.833 E_circle 1.479 E_mmd 0.044
# [0.001]
# [Train][297] Loss: E 2.839 E_pred 1.792 E_circle 1.429 E_mmd 0.047
# [0.001]
# [Train][298] Loss: E 2.896 E_pred 1.813 E_circle 1.473 E_mmd 0.049
# [0.001]
# [Train][299] Loss: E 2.937 E_pred 1.844 E_circle 1.483 E_mmd 0.047
# [0.001]
# [Train][300] Loss: E 2.897 E_pred 1.798 E_circle 1.489 E_mmd 0.045
# [0.001]
# [Train][301] Loss: E 3.004 E_pred 1.856 E_circle 1.545 E_mmd 0.049
# [0.001]
# [Train][302] Loss: E 2.855 E_pred 1.804 E_circle 1.410 E_mmd 0.046
# [0.001]
# [Train][303] Loss: E 2.834 E_pred 1.779 E_circle 1.409 E_mmd 0.046
# [0.001]
# [Train][304] Loss: E 2.889 E_pred 1.822 E_circle 1.424 E_mmd 0.043
# [0.001]
# [Train][305] Loss: E 2.836 E_pred 1.770 E_circle 1.410 E_mmd 0.048
# [0.001]
# [Train][306] Loss: E 2.875 E_pred 1.803 E_circle 1.418 E_mmd 0.044
# [0.001]
# [Train][307] Loss: E 2.899 E_pred 1.801 E_circle 1.448 E_mmd 0.044
# [0.001]
# [Train][308] Loss: E 2.916 E_pred 1.800 E_circle 1.461 E_mmd 0.049
# [0.001]
# [Train][309] Loss: E 2.895 E_pred 1.794 E_circle 1.437 E_mmd 0.046
# [0.001]
# [Train][310] Loss: E 2.892 E_pred 1.795 E_circle 1.428 E_mmd 0.046
# [0.001]
# [Train][311] Loss: E 2.935 E_pred 1.824 E_circle 1.437 E_mmd 0.049
# [0.001]
# [Train][312] Loss: E 2.930 E_pred 1.808 E_circle 1.444 E_mmd 0.052
# [0.001]
# [Train][313] Loss: E 2.891 E_pred 1.796 E_circle 1.405 E_mmd 0.049
# [0.001]
# [Train][314] Loss: E 2.875 E_pred 1.807 E_circle 1.369 E_mmd 0.045
# [0.001]
# [Train][315] Loss: E 2.971 E_pred 1.838 E_circle 1.441 E_mmd 0.051
# [0.001]
# [Train][316] Loss: E 2.931 E_pred 1.822 E_circle 1.412 E_mmd 0.045
# [0.001]
# [Train][317] Loss: E 2.977 E_pred 1.832 E_circle 1.447 E_mmd 0.051
# [0.001]
# [Train][318] Loss: E 2.987 E_pred 1.833 E_circle 1.451 E_mmd 0.053
# [0.001]
# [Train][319] Loss: E 2.924 E_pred 1.789 E_circle 1.420 E_mmd 0.053
# [0.001]
# [Train][320] Loss: E 2.927 E_pred 1.806 E_circle 1.403 E_mmd 0.048
# [0.001]
# [Train][321] Loss: E 2.927 E_pred 1.795 E_circle 1.410 E_mmd 0.050
# [0.001]
# [Train][322] Loss: E 2.899 E_pred 1.795 E_circle 1.373 E_mmd 0.047
# [0.001]
# [Train][323] Loss: E 2.928 E_pred 1.816 E_circle 1.374 E_mmd 0.050
# [0.001]
# [Train][324] Loss: E 2.912 E_pred 1.795 E_circle 1.377 E_mmd 0.048
# [0.001]
# [Train][325] Loss: E 2.914 E_pred 1.783 E_circle 1.390 E_mmd 0.049
# [0.001]
# [Train][326] Loss: E 2.867 E_pred 1.762 E_circle 1.348 E_mmd 0.052
# [0.001]
# [Train][327] Loss: E 2.881 E_pred 1.769 E_circle 1.351 E_mmd 0.054
# [0.001]
# [Train][328] Loss: E 2.956 E_pred 1.832 E_circle 1.362 E_mmd 0.054
# [0.001]
# [Train][329] Loss: E 2.965 E_pred 1.850 E_circle 1.352 E_mmd 0.046
# [0.001]
# [Train][330] Loss: E 3.044 E_pred 1.843 E_circle 1.443 E_mmd 0.059
# [0.001]
# [Train][331] Loss: E 2.914 E_pred 1.780 E_circle 1.358 E_mmd 0.054
# [0.001]
# [Train][332] Loss: E 2.924 E_pred 1.783 E_circle 1.362 E_mmd 0.055
# [0.001]
# [Train][333] Loss: E 2.959 E_pred 1.798 E_circle 1.379 E_mmd 0.056
# [0.001]
# [Train][334] Loss: E 2.920 E_pred 1.788 E_circle 1.342 E_mmd 0.053
# [0.001]
# [Train][335] Loss: E 2.975 E_pred 1.810 E_circle 1.375 E_mmd 0.056
# [0.001]
# [Train][336] Loss: E 2.921 E_pred 1.787 E_circle 1.336 E_mmd 0.052
# [0.001]
# [Train][337] Loss: E 3.018 E_pred 1.845 E_circle 1.377 E_mmd 0.055
# [0.001]
# [Train][338] Loss: E 2.946 E_pred 1.798 E_circle 1.340 E_mmd 0.057
# [0.001]
# [Train][339] Loss: E 2.907 E_pred 1.767 E_circle 1.331 E_mmd 0.052
# [0.001]
# [Train][340] Loss: E 2.903 E_pred 1.771 E_circle 1.316 E_mmd 0.052
# [0.001]
# [Train][341] Loss: E 3.008 E_pred 1.825 E_circle 1.370 E_mmd 0.055
# [0.001]
# [Train][342] Loss: E 2.912 E_pred 1.795 E_circle 1.289 E_mmd 0.052
# [0.001]
# [Train][343] Loss: E 2.804 E_pred 1.749 E_circle 1.214 E_mmd 0.049
# [0.001]
# [Train][344] Loss: E 2.952 E_pred 1.821 E_circle 1.295 E_mmd 0.054
# [0.001]
# [Train][345] Loss: E 2.948 E_pred 1.771 E_circle 1.341 E_mmd 0.057
# [0.001]
# [Train][346] Loss: E 2.934 E_pred 1.778 E_circle 1.309 E_mmd 0.061
# [0.001]
# [Train][347] Loss: E 2.884 E_pred 1.749 E_circle 1.277 E_mmd 0.065
# [0.001]
# [Train][348] Loss: E 2.922 E_pred 1.800 E_circle 1.267 E_mmd 0.054
# [0.001]
# [Train][349] Loss: E 2.972 E_pred 1.804 E_circle 1.312 E_mmd 0.059
# [0.001]
# [Train][350] Loss: E 2.984 E_pred 1.821 E_circle 1.303 E_mmd 0.057
# [0.001]
# [Train][351] Loss: E 2.942 E_pred 1.797 E_circle 1.283 E_mmd 0.051
# [0.001]
# [Train][352] Loss: E 2.909 E_pred 1.749 E_circle 1.289 E_mmd 0.060
# [0.001]
# [Train][353] Loss: E 2.944 E_pred 1.786 E_circle 1.286 E_mmd 0.056
# [0.001]
# [Train][354] Loss: E 2.982 E_pred 1.810 E_circle 1.301 E_mmd 0.052
# [0.001]
# [Train][355] Loss: E 2.950 E_pred 1.781 E_circle 1.291 E_mmd 0.056
# [0.001]
# [Train][356] Loss: E 2.913 E_pred 1.791 E_circle 1.230 E_mmd 0.058
# [0.001]
# [Train][357] Loss: E 2.845 E_pred 1.754 E_circle 1.192 E_mmd 0.057
# [0.001]
# [Train][358] Loss: E 2.962 E_pred 1.795 E_circle 1.274 E_mmd 0.058
# [0.001]
# [Train][359] Loss: E 2.954 E_pred 1.769 E_circle 1.285 E_mmd 0.062
# [0.001]
# [Train][360] Loss: E 2.930 E_pred 1.766 E_circle 1.257 E_mmd 0.063
# [0.001]
# [Train][361] Loss: E 2.914 E_pred 1.781 E_circle 1.220 E_mmd 0.061
# [0.001]
# [Train][362] Loss: E 3.036 E_pred 1.844 E_circle 1.284 E_mmd 0.060
# [0.001]
# [Train][363] Loss: E 3.011 E_pred 1.830 E_circle 1.267 E_mmd 0.061
# [0.001]
# [Train][364] Loss: E 2.986 E_pred 1.795 E_circle 1.275 E_mmd 0.059
# [0.001]
# [Train][365] Loss: E 2.931 E_pred 1.754 E_circle 1.257 E_mmd 0.057
# [0.001]
# [Train][366] Loss: E 3.059 E_pred 1.822 E_circle 1.317 E_mmd 0.060
# [0.001]
# [Train][367] Loss: E 2.995 E_pred 1.806 E_circle 1.265 E_mmd 0.054
# [0.001]
# [Train][368] Loss: E 2.913 E_pred 1.757 E_circle 1.220 E_mmd 0.059
# [0.001]
# [Train][369] Loss: E 2.918 E_pred 1.772 E_circle 1.205 E_mmd 0.060
# [0.001]
# [Train][370] Loss: E 2.929 E_pred 1.781 E_circle 1.202 E_mmd 0.061
# [0.001]
# [Train][371] Loss: E 2.923 E_pred 1.735 E_circle 1.239 E_mmd 0.064
# [0.001]
# [Train][372] Loss: E 2.967 E_pred 1.784 E_circle 1.231 E_mmd 0.063
# [0.001]
# [Train][373] Loss: E 3.013 E_pred 1.815 E_circle 1.241 E_mmd 0.065
# [0.001]
# [Train][374] Loss: E 3.004 E_pred 1.786 E_circle 1.257 E_mmd 0.068
# [0.001]
# [Train][375] Loss: E 2.947 E_pred 1.760 E_circle 1.224 E_mmd 0.063
# [0.001]
# [Train][376] Loss: E 3.014 E_pred 1.801 E_circle 1.251 E_mmd 0.059
# [0.001]
# [Train][377] Loss: E 3.005 E_pred 1.787 E_circle 1.249 E_mmd 0.064
# [0.001]
# [Train][378] Loss: E 3.021 E_pred 1.803 E_circle 1.244 E_mmd 0.065
# [0.001]
# [Train][379] Loss: E 2.962 E_pred 1.770 E_circle 1.212 E_mmd 0.065
# [0.001]
# [Train][380] Loss: E 2.970 E_pred 1.758 E_circle 1.228 E_mmd 0.067
# [0.001]
# [Train][381] Loss: E 2.950 E_pred 1.759 E_circle 1.206 E_mmd 0.063
# [0.001]
# [Train][382] Loss: E 2.974 E_pred 1.767 E_circle 1.220 E_mmd 0.062
# [0.001]
# [Train][383] Loss: E 2.937 E_pred 1.768 E_circle 1.178 E_mmd 0.060
# [0.001]
# [Train][384] Loss: E 2.962 E_pred 1.790 E_circle 1.177 E_mmd 0.060
# [0.001]
# [Train][385] Loss: E 2.949 E_pred 1.784 E_circle 1.167 E_mmd 0.060
# [0.001]
# [Train][386] Loss: E 3.011 E_pred 1.779 E_circle 1.229 E_mmd 0.066
# [0.001]
# [Train][387] Loss: E 3.014 E_pred 1.786 E_circle 1.222 E_mmd 0.064
# [0.001]
# [Train][388] Loss: E 3.014 E_pred 1.763 E_circle 1.244 E_mmd 0.063
# [0.001]
# [Train][389] Loss: E 3.095 E_pred 1.809 E_circle 1.266 E_mmd 0.074
# [0.001]
# [Train][390] Loss: E 2.993 E_pred 1.760 E_circle 1.217 E_mmd 0.063
# [0.001]
# [Train][391] Loss: E 3.042 E_pred 1.779 E_circle 1.240 E_mmd 0.068
# [0.001]
# [Train][392] Loss: E 2.960 E_pred 1.782 E_circle 1.157 E_mmd 0.060
# [0.001]
# [Train][393] Loss: E 2.947 E_pred 1.771 E_circle 1.151 E_mmd 0.060
# [0.001]
# [Train][394] Loss: E 3.024 E_pred 1.789 E_circle 1.205 E_mmd 0.064
# [0.001]
# [Train][395] Loss: E 2.949 E_pred 1.760 E_circle 1.154 E_mmd 0.064
# [0.001]
# [Train][396] Loss: E 3.062 E_pred 1.785 E_circle 1.231 E_mmd 0.075
# [0.001]
# [Train][397] Loss: E 3.031 E_pred 1.810 E_circle 1.180 E_mmd 0.065
# [0.001]
# [Train][398] Loss: E 3.001 E_pred 1.757 E_circle 1.194 E_mmd 0.072
# [0.001]
# [Train][399] Loss: E 3.009 E_pred 1.769 E_circle 1.192 E_mmd 0.064
# [0.0005]
# CPU times: user 3min 34s, sys: 4.3 s, total: 3min 38s
# Wall time: 16.7 s

# %%
figsize(6,3)
skip=10
N = len(loss_curve['E'])-skip
plt.plot(np.arange(N),loss_curve['E'][skip:],label='E')
plt.plot(np.arange(N),loss_curve['E_pred'][skip:],label='E_pred')
plt.plot(np.arange(N),loss_curve['E_circle'][skip:],label='E_circle')
plt.plot(np.arange(N),loss_curve['E_mmd'][skip:],label='E_mmd')
plt.legend()

# %%
testmodel.modeleval()
scembedding = testmodel.netE(torch.tensor(scdata.values,dtype=torch.float32).cuda())
stembedding = testmodel.netE(torch.tensor(stdata.values,dtype=torch.float32).cuda())
netst2sc = F.softmax(stembedding.mm(scembedding.t()),dim=1).detach().cpu().numpy()
netsc2st = F.softmax(scembedding.mm(stembedding.t()),dim=1).detach().cpu().numpy()

# %%
np.save('result/230215_testdp_pure_mmd-E3z2.npy',netst2sc)
np.save('result/230215_testdp_pure_sc2st_mmd-E3z2.npy',netsc2st)
np.save('result/230215_scembbedding-E3z2.npy',scembedding.detach().cpu().numpy())
np.save('result/230215_stembbedding-E3z2.npy',stembedding.detach().cpu().numpy())

# %%
testmodel.save()

# %%
celltypelist=stgtcelltype.columns[((stgtcelltype>0.1).sum(0)>10)].tolist()
print(celltypelist)
# Out:
# ['Allantois', 'Anterior somitic tissues', 'Blood progenitors', 'Cardiomyocytes', 'Cranial mesoderm', 'Dermomyotome', 'Endothelium', 'Erythroid', 'Forebrain/Midbrain/Hindbrain', 'Gut tube', 'Haematoendothelial progenitors', 'Intermediate mesoderm', 'Lateral plate mesoderm', 'Mixed mesenchymal mesoderm', 'Neural crest', 'Presomitic mesoderm', 'Sclerotome', 'Spinal cord', 'Splanchnic mesoderm', 'Surface ectoderm']

# %%
figsize(18,15)
for i in range(len(celltypelist)):
    subplot(4,6,i+1)
    name = celltypelist[i]
    spinalcord = netst2sc[:,scmetadata.celltype_mapped_refined==name].mean(1)    
    plt.scatter(spcoor.coord_x,-spcoor.coord_y,c = spinalcord,cmap='Reds',s=10)
    plt.title(name)
    plt.xticks([])
    plt.yticks([])

# %%
import scipy
pr_spaotsc=[]
for i in range(stgtcelltype.shape[1]):
    name = stgtcelltype.columns[i]
    scl =  netst2sc[:,scmetadata.celltype_mapped_refined==name].mean(1)    
    pearson = scipy.stats.pearsonr(stgtcelltype.iloc[:,i],scl)[0]
    pr_spaotsc.append(pearson)
    if np.isnan(pearson):
        pearson=0
    print(pearson,'\t',stgtcelltype.columns[i])
pr_spaotsc = pd.DataFrame(pr_spaotsc,index=stgtcelltype.columns).T
# Out:
# 0.8808100258148785 	 Allantois
# 0.577450580240425 	 Anterior somitic tissues
# 0.2552591300598884 	 Blood progenitors
# 0.907695871983516 	 Cardiomyocytes
# 0.8456377016958454 	 Cranial mesoderm
# 0.6268909101295722 	 Definitive endoderm
# 0.84366650142375 	 Dermomyotome
# 0.7456169196587271 	 Endothelium
# 0.8555543721970011 	 Erythroid
# 0.12471966409345 	 ExE endoderm
# 0.9410474667819978 	 Forebrain/Midbrain/Hindbrain
# 0.9501991127831089 	 Gut tube
# 0.5027005178860795 	 Haematoendothelial progenitors
# 0.6783368322249427 	 Intermediate mesoderm
# 0.8906458346039259 	 Lateral plate mesoderm
# 0.8088987022263823 	 Mixed mesenchymal mesoderm
# 0.8920278215264333 	 NMP
# 0.7879834711650834 	 Neural crest
# 0.9640711226459379 	 Presomitic mesoderm
# 0.7327631066582233 	 Sclerotome
# 0.8418611476855866 	 Spinal cord
# 0.8995823044770795 	 Splanchnic mesoderm
# 0.8789457326845977 	 Surface ectoderm
